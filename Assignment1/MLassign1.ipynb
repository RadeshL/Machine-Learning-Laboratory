# %%
import pandas as pd

# %%
def eda(file):
    df = pd.read_csv(file)
    print(df.head())

# %%
file = "./test_Y3wMUE5_7gLdaTN.csv"
eda(file)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
x = df.columns
y = df.isnull().sum()
plt.xticks(rotation=45, ha='right')
plt.bar(x,y)
# Out:
# <BarContainer object of 12 artists>

# %%
df.shape
# Out:
# (367, 12)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import scipy.stats as stats
df["ApplicantIncome"].plot(kind = "hist", bins=30)
plt.title("Application Income Histogram")
plt.show()
df["ApplicantIncome"].plot(kind = "kde")
plt.title("Application Income KDE")
plt.show()
df.boxplot(column=["ApplicantIncome"])
plt.title("Application Income Boxplot")
plt.show()
stats.probplot(df["ApplicantIncome"], dist="norm", plot=plt)
plt.title("Application Income Q-Q Plot")
plt.show()

# %%
df["LoanAmount"].plot(kind = "hist", bins=30)
plt.title("LoanAmount Histogram")
plt.show()
df["LoanAmount"].plot(kind = "kde")
plt.title("LoanAmount KDE")
plt.show()
df.boxplot(column=["LoanAmount"])
plt.title("LoanAmount Boxplot")
plt.show()
stats.probplot(df["LoanAmount"], dist="norm", plot=plt)
plt.title("LoanAmount Q-Q Plot")
plt.show()

# %%
df["Loan_Amount_Term"].plot(kind = "hist", bins=30)
plt.title("Loan_Amount_Term Histogram")
plt.show()
df["Loan_Amount_Term"].plot(kind = "kde")
plt.title("Loan_Amount_Term KDE")
plt.show()
df.boxplot(column=["Loan_Amount_Term"])
plt.title("Loan_Amount_Term Boxplot")
plt.show()
stats.probplot(df["Loan_Amount_Term"], dist="norm", plot=plt)
plt.title("Loan_Amount_Term Q-Q Plot")
plt.show()

# %%
df["Credit_History"].plot(kind = "hist", bins=30)
plt.title("Credit_History Histogram")
plt.show()
df["Credit_History"].plot(kind = "kde")
plt.title("Credit_History KDE")
plt.show()
df.boxplot(column=["Credit_History"])
plt.title("Credit_History Boxplot")
plt.show()
stats.probplot(df["Credit_History"], dist="norm", plot=plt)
plt.title("Credit_History Q-Q Plot")
plt.show()

# %%
import numpy as np
df["ApplicantIncome"] = np.log1p(df["ApplicantIncome"])
df["ApplicantIncome"].plot(kind="kde")
plt.title("Applicant Income KDE")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df["ApplicantIncome"] = scaler.fit_transform(df[["ApplicantIncome"]])

# %%
df["ApplicantIncome"].plot(kind="kde")
plt.title("Applicant Income KDE")
plt.show()

# %%
import numpy as np
df["LoanAmount"] = np.log1p(df["LoanAmount"])
df["LoanAmount"].plot(kind="kde")
plt.title("Loan Amount KDE")
plt.show()
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df["LoanAmount"] = scaler.fit_transform(df[["LoanAmount"]])
df["LoanAmount"].plot(kind="kde")
plt.title("Loan Amount KDE")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df["Credit_History"] = scaler.fit_transform(df[["Credit_History"]])
df["Credit_History"].plot(kind="kde")
plt.title("Credit History KDE")
plt.show()

# %%
import seaborn as sns
sns.boxplot(x = df["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
from scipy.stats import zscore

z_score_out = zscore(df["ApplicantIncome"])

outliers_z = df[abs(z_score_out) > 3]

# %%
outliers_z
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 25   LP001153    Male      No          0      Graduate            No
# 81   LP001428    Male     Yes         3+      Graduate            No
# 116  LP001607  Female      No          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 25        -10.069978              24000    0.405815             360.0
# 81          3.592417                  0    2.540834             360.0
# 116       -10.069978               1760    0.875195             360.0
#
#      Credit_History Property_Area
# 25        -2.174584         Rural
# 81         0.459858         Urban
# 116        0.459858     Semiurban

# %%
Q1 = df["ApplicantIncome"].quantile(0.25)
Q3 = df["ApplicantIncome"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers_iqr = df[
    (df["ApplicantIncome"] < lower) |
    (df["ApplicantIncome"] > upper)
]

outliers_iqr
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 13   LP001094    Male     Yes          2      Graduate           NaN
# 25   LP001153    Male      No          0      Graduate            No
# 81   LP001428    Male     Yes         3+      Graduate            No
# 91   LP001483    Male     Yes         3+      Graduate            No
# 116  LP001607  Female      No          0  Not Graduate            No
# 119  LP001622    Male     Yes          2      Graduate            No
# 124  LP001655  Female      No          0      Graduate            No
# 143  LP001791    Male     Yes          0      Graduate           Yes
# 145  LP001797  Female      No          0      Graduate            No
# 166  LP001933    Male      No          2  Not Graduate            No
# 179  LP002017    Male     Yes         3+      Graduate            No
# 188  LP002057    Male     Yes          0  Not Graduate            No
# ...

# %%
outliers = pd.merge(outliers_iqr,outliers_z)

# %%
outliers
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001153    Male      No          0      Graduate            No
# 1  LP001428    Male     Yes         3+      Graduate            No
# 2  LP001607  Female      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0       -10.069978              24000    0.405815             360.0
# 1         3.592417                  0    2.540834             360.0
# 2       -10.069978               1760    0.875195             360.0
#
#    Credit_History Property_Area
# 0       -2.174584         Rural
# 1        0.459858         Urban
# 2        0.459858     Semiurban

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')
